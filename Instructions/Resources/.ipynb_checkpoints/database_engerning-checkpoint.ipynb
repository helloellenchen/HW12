# %%
# Dependencies
import pandas as pd

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy import create_engine, MetaData
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, ForeignKey, Integer, String, Numeric, Text, Float
from sqlalchemy.orm import Session

# %%
# Load the cleaned csv file into a pandas dataframe
df_measurements = pd.read_csv('clean_hawaii_measurements.csv')
df_stations = pd.read_csv('clean_hawaii_stations.csv')
df_measurements.head()
# Out:
#        station        date  prcp  tobs
# 0  USC00519397  2010-01-01  0.08    65
# 1  USC00519397  2010-01-02  0.00    63
# 2  USC00519397  2010-01-03  0.00    74
# 3  USC00519397  2010-01-04  0.00    76
# 4  USC00519397  2010-01-06  0.00    73

# %%
# Create lists from dataframes (to_dict() cleans out DataFrame metadata)
#  Ref: http://pandas-docs.github.io/pandas-docs-travis/io.html#orient-options
measurements_data = df_measurements.to_dict(orient='records')
stations_data = df_stations.to_dict(orient='records')

# %%
# Make sure data looks good
#print(stations_data)
print(measurements_data)
# Out:
# [{'date': '2010-01-01', 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 65}, {'date': '2010-01-02', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 63}, {'date': '2010-01-03', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74}, {'date': '2010-01-04', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76}, {'date': '2010-01-06', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73}, {'date': '2010-01-07', 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 70}, {'date': '2010-01-08', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 64}, {'date': '2010-01-09', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68}, {'date': '2010-01-10', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73}, {'date': '2010-01-11', 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 64}, {'date': '2010-01-12', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 61}, {'date': '2010-01-14', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 66}, {'date': '2010-01-15', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 65}, {'date': '2010-01-16', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68}, {'date': '2010-01-17', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 64}, {'date': '2010-01-18', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72}, {'date': '2010-01-19', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 66}, {'date': '2010-01-20', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 66}, {'date': '2010-01-21', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69}, {'date': '2010-01-22', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67}, {'date': '2010-01-23', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67}, {'date': '2010-01-24', 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 71}, {'date': '2010-01-25', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67}, {'date': '2010-01-26', 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 76}, {'date': '2010-01-27', 'prcp': 0.12, 'station': 'USC00519397', 'tobs': 68}, {'date': '2010-01-28', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72}, {'date': '2010-01-30', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 70}, {'date': '2010-01-31', 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 67}, {'date': '2010-02-01', 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 66}, {'date': '2010-02-03', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67}, {'date': '2010-02-04', 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 69}, {'date': '2010-02-05', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67}, {'date': '2010-02-06', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67}, {'date': '2010-02-07', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 64}, {'date': '2010-02-08', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69}, {'date': '2010-02-09', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73}, {'date': '2010-02-11', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73}, {'date': '2010-02-12', 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 69}, {'date': '2010-02-13', 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 69}, {'date': '2010-02-14', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69}, {'date': '2010-02-15', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 71}, {'date': '2010-02-16', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 61}, {'date': '2010-02-17', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69}, {'date': '2010-02-19', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 63}, {'date': '2010-02-20', 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 64}, {'date': '2010-02-21', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 65}, {'date': '2010-02-22', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67}, {'date': '2010-02-23', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68}, {'date': '2010-02-24', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 65}, {'date': '2010-02-25', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76}, {'date': '2010-02-26', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75}, {'date': '2010-02-28', 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 66}, {'date': '2010-03-01', 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 70}, {'date': '2 ...

# %%
# Create an engine to a SQLite database file called `hawaii.sqlite`
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
# Create a connection to the engine called `conn`
conn = engine.connect()

# %%
# Use `declarative_base` from SQLAlchemy to model the tables as an ORM class
Base = declarative_base()

# %%
# Create Measurement Class
# ----------------------------------
class Measurements(Base):
    __tablename__ = 'measurements'
    id = Column(Integer, primary_key=True)
    station = Column(String(15))
    date = Column(String(15))
    prcp = Column(Float)
    tobs = Column(Integer)

    def __repr__(self):
        return "id={self.id}, name={self.name}"

# %%
# Create Station class
# ---------------------------------------
class Station(Base):
    __tablename__ = 'station'
    id = Column(Integer, primary_key=True)
    station = Column(String(15))
    name = Column(String(45))
    latitude = Column(Float)
    longitude = Column(Float)
    elevation = Column(Float)
    
    def __repr__(self):
        return "id={self.id}, name={self.name}"

# %%
# Using `create_all`, creates the tables in the database
Base.metadata.create_all(engine)

# %%
# Use Orient='records' to create a list of data to write
weather_data = df_measurements.to_dict(orient='records')
station_data = df_stations.to_dict(orient='records')
weather_data[0]
# Out:
# {'date': '2010-01-01', 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 65}

# %%
# Use MetaData from SQLAlchemy to reflect the tables

metadata = MetaData(bind=engine)
metadata.reflect()

# %%
# Save the reference to the `demographics` table as a variable called `table`

weather_table = sqlalchemy.Table('measurements', metadata, autoload=True)
station_table = sqlalchemy.Table('station', metadata, autoload=True)

# %%
# Use `table.delete()` to remove any existing data.
# Note that this is a convenience function so that you can re-run the example code multiple times.
# You would not likely do this step in production.

conn.execute(weather_table.delete())
conn.execute(station_table.delete())

# %%
# Use `table.insert()` to insert the data into the table

conn.execute(weather_table.insert(), weather_data)
conn.execute(station_table.insert(), station_data)

# %%
# Test that the insert works by fetching the first 5 rows. 
conn.execute("select * from measurements limit 5").fetchall()
# Out:
# [(1, 'USC00519397', '2010-01-01', 0.08, 65),
#  (2, 'USC00519397', '2010-01-02', 0.0, 63),
#  (3, 'USC00519397', '2010-01-03', 0.0, 74),
#  (4, 'USC00519397', '2010-01-04', 0.0, 76),
#  (5, 'USC00519397', '2010-01-06', 0.0, 73)]
